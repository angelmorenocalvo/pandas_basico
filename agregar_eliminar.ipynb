# %%
import pandas as pd
import numpy as np

# %%
df_books = pd.read_csv('/content/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv')

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# ## Drop columns

# %%
df_books.drop('Genre', axis=1).head(2) # 1 referente a columnas 0 a filas
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %% [markdown]
# para borrarlo directamente del dataframe

# %%
 df_books.drop('Genre', axis=1, inplace=True)
 df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %% [markdown]
# Otra opción

# %%
df_books = df_books.drop('Year', axis=1)

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %% [markdown]
# con del, función propia de python

# %%
del df_books['Price']

# %% [markdown]
# ## Borrar columnas

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Year
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350  2016
# 1              11/22/63: A Novel  Stephen King          4.6     2052  2011

# %%
df_books.drop(0, axis=0).head(2)
# Out:
#                                       Name              Author  User Rating  \
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Year
# 1     2052  2011
# 2    18979  2018

# %%
df_books.drop([1,2,4], axis=0).head(2)
# Out:
#                             Name         Author  User Rating  Reviews  Year
# 0  10-Day Green Smoothie Cleanse       JJ Smith          4.7    17350  2016
# 3         1984 (Signet Classics)  George Orwell          4.7    21424  2017

# %%
df_books.drop(range(0,10), axis=0).head(2)
# Out:
#                                                  Name            Author  \
# 10                          A Man Called Ove: A Novel   Fredrik Backman
# 11  A Patriot's History of the United States: From...  Larry Schweikart
#
#     User Rating  Reviews  Year
# 10          4.6    23848  2017
# 11          4.6      460  2010

# %% [markdown]
# ## Añadir columnas

# %%
df_books.head(3)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Year
# 0    17350  2016
# 1     2052  2011
# 2    18979  2018

# %%
df_books['Nueva_columna'] = np.nan
df_books.head(4)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
# 3                   1984 (Signet Classics)       George Orwell          4.7
#
#    Reviews  Year  Nueva_columna
# 0    17350  2016            NaN
# 1     2052  2011            NaN
# 2    18979  2018            NaN
# 3    21424  2017            NaN

# %%
df_books.shape[0]# filas
# Out:
# 550

# %%
data = np.arange(0, df_books.shape[0])
data

# %%
df_books['Rango'] = data

# %%
df_books.head(4)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
# 3                   1984 (Signet Classics)       George Orwell          4.7
#
#    Reviews  Year  Nueva_columna  Rango
# 0    17350  2016            NaN      0
# 1     2052  2011            NaN      1
# 2    18979  2018            NaN      2
# 3    21424  2017            NaN      3

# %% [markdown]
# ## Agregar filas

# %%
df_books.append(df_books)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Year  Nueva_columna  \
# 0                    JJ Smith          4.7    17350  2016            NaN
# 1                Stephen King          4.6     2052  2011            NaN
# 2          Jordan B. Peterson          4.7    18979  2018            NaN
# ...
