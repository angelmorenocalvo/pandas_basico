# %%
import pandas as pd

# %% [markdown]
# desde lista con indice propio

# %%
psg_players = pd.Series(['Navas', 'Mbappe', 'Neymar', 'Messi'],
          index=[1,7,10,30]
          )
psg_players
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %% [markdown]
# con lista sin indice

# %%
pd.Series(['Navas', 'Mbappe', 'Neymar', 'Messi'])
# Out:
# 0     Navas
# 1    Mbappe
# 2    Neymar
# 3     Messi
# dtype: object

# %% [markdown]
# con diccionario

# %%
dic = {1:'Navas', 7:'Mbappe', 10:'Neymar', 30:'Messi'}
pd.Series(dic)
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players[1]
# Out:
# 'Navas'

# %%
psg_players[10]
# Out:
# 'Neymar'

# %%
psg_players[0:3]# tambien permiten slicing
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# dtype: object

# %%
dict = {'Jugador': ['Navas', 'Mbappe', 'Neymar', 'Messi'], 
 'Altura':[183.0,170.0,170.0,165.0],
 'Goles':[2,200,200,200]}

df_Players = pd.DataFrame(dict)
df_Players
# Out:
#   Jugador  Altura  Goles
# 0   Navas   183.0      2
# 1  Mbappe   170.0    200
# 2  Neymar   170.0    200
# 3   Messi   165.0    200

# %%
df_Players.columns
# Out:
# Index(['Jugador', 'Altura', 'Goles'], dtype='object')

# %%
df_Players.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df_Players = pd.DataFrame(dict, index=[1,7,10,30])

# %%
df_Players.index
# Out:
# Int64Index([1, 7, 10, 30], dtype='int64')
